# %% [markdown]
# ## Задание 1

# %%
import requests
from nltk import sent_tokenize
# Out:
# D:\Conda\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
url = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt'
response = requests.get(url)
text = response.text.lower()

corpus_length = len(text)
print(f"А) Длина всего корпуса: {corpus_length} символов")

sentences = sent_tokenize(text)
num_sentences = len(sentences)
print(f"Б) Количество предложений: {num_sentences}")

chars = set(text)
num_unique_characters = len(chars)
print(f"В) Сколько всего символов используется: {num_unique_characters}")

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# А) Длина всего корпуса: 600901 символов
# Б) Количество предложений: 2864
# В) Сколько всего символов используется: 59

# %%
import numpy as np

# %% [markdown]
# ## Задание 2

# %%
maxlen = 40
step = 3
sentences = []
next_chars = [] 
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# nb sequences: 200287
# Vectorization...

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import LambdaCallback

# %% [markdown]
# ## Задание 3

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Функция, вызываемая в конце каждой эпохи для генерации текста
def on_epoch_end(epoch, _):
    print()
    print('----- Генерация текста после эпохи: %d' % epoch)

    start_index = np.random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0]:
        print('----- Разнообразие:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Создание текста: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

        print(generated)

# Callback для вызова функции в конце каждой эпохи
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# Обучение модели
model.fit(x, y, batch_size=128, epochs=20, callbacks=[print_callback])

# Проверка работы модели в онлайн-режиме
start_index = np.random.randint(0, len(text) - maxlen - 1)
for diversity in [0.2, 0.5, 1.0]:
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('----- Создание текста: "' + sentence + '"')

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_indices[char]] = 1.

        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]

        generated += next_char
        sentence = sentence[1:] + next_char

    print(generated)
# Out:
# Epoch 1/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 2.5298
# ----- Генерация текста после эпохи: 0
# ----- Разнообразие: 0.2
# ----- Создание текста: "far been the noblest and
# remotest sentim"
# far been the noblest and
# remotest sentiment and of the the the the the the the the the the the the the the soun the the the the sere the the the the sere the the the the the the the the the ther and the the the the the the the the the the the mont and and the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the stich the the the the the the the the the th
# ----- Разнообразие: 0.5
# ----- Создание текста: "far been the noblest and
# remotest sentim"
# far been the noblest and
# remotest sentime to er the rically--ace mact art and in seande of ar efalher wathe sicaldity go lere the the destorme the the mest of mand the dorede sters in the the whe hand of the the thim with hanter and it an andalle the and all thas gere ander andereline cotuliny of the hing the the
# serent one the ise al and mingist, and the soull the whor ande the that and the the the hat the mere so lad the sithan the ma
# ----- Разнообразие: 1.0
# ----- Создание текста: "far been the noblest and
# remotest sentim"
# far been the noblest and
# remotest sentimotimasy-tuous ant
# invitimady tha terest one,iwits ind the ast omem old atters the
#
# ceat in the wat at ureves , wh mheersalce, to ispuraperdathanc itieat,. himshibess, gare "iriere hamd aelo at theco womath selive. an al" mtien outh, atseusigladersthig the resede houre
# "aantitt sy-wout ve
# l
# af bep, co perics
# eata hwt rvere iofricg of at inssiontere tho deve pom,! whe couiv, and waind,  poreds, wamt
# 1565/1565 [==============================] - 94s 60ms/step - loss: 2.5297
# Epoch 2/20
# 1565/1565 [==============================] - ETA: 0s - loss: 2.1733
# ----- Генерация текста после эпохи: 1
# ----- Разнообразие: 0.2
# ----- Создание текста: "sical
# explanations, because they make hi"
# sical
# explanations, because they make his of the reantion the sereation the and and and and and and and and and the and and and and and and and and and and and and and in the the hand and and and and and in the the soul the preation the soule the which rean the somention the the han the serion of the ereation the proustion the and and and and and and and and and and and and and and and and the and the and and whith and is of the and and
# ----- Разнообразие: 0.5
# ----- Создание текста: "sical
# explanations, because they make hi"
# sical
# explanations, because they make his be that the singe and an ous in the sopely as the which ous wathen and and and in as and and ar ally the and of the hare of thes to and halision and the mare the reald, and of it in which in the pranotion that on it at of the of and as to has ar is mathere sian in the has of the for of as al the the and cithing ta lough is the mas in the eadion, be preantion to the the ration is be veroubly as a
# ----- Разнообразие: 1.0
# ----- Создание текста: "sical
# explanations, because they make hi"
# sical
# explanations, because they make hice cabease of tho. sterumauty wailate of of hearny fon te wextind and inverithi, by poinar bighe is ancex pration copcousota ildicescive to all an ra nom of the ther and berisueh fur in, in njotarely
# -2=an shew,
# dendely the -in d arfurve rave is proppreiver of revestiit. of
# araredven posteenty--priers im t; themeste himus that the mongens; the sealttiintelt, implais ous aut puspeicely lyoup of rat
# 1565/1565 [==============================] - 85s 55ms/step - loss: 2.1733
# Epoch 3/20
# 1565/1565 [==============================] - ETA: 0s - loss: 2.0434
# ----- Генерация текста после эпохи: 2
# ----- Разнообразие: 0.2
# ----- Создание текста: " of men. he must be content with
# such a "
#  of men. he must be content with
# such a to the insting of the sould and the sound and the soment the experate and the perone the sound and and and and and the sond and in the senting of the songer in the sound of the pronoment and and the songer and and the some the sond the sond and the mand the sond in the sond in the songer and the some in the sond the sond the sond and the expention of the sound the experion to the in the soul the s
# ----- Разнообразие: 0.5
# ----- Создание текста: " of men. he must be content with
# such a "
#  of men. he must be content with
# such a to ses the purses into the fortion of the his a soblited in the excasion to sean songing of the promons and and for the intine of the loug of the exenting of the revery and not the eaning and and and the renother and on gidation and have is never and histere for nes in or or it in the song the for be for the ever on and the mare of the sich and has be not is be as and some the seal and mone to con
# ----- Разнообразие: 1.0
# ----- Создание текста: " of men. he must be content with
# such a "
#  of men. he must be content with
# such a cause is. they as, and of alm than sees suredes
# porvery of thar is fort usneston wly the evear lof to prees in of toplente. rishceop caplly meras. hom ir ither be wo and mant incion. aesed lilituicy vesily antimelucomen concectien fralusery of ades ranestien "uront as cediculys perhen the to lend has, bean is suth st wat hashscuted and rosence an frirhthe hyseld-wh there to the ond
# queosse, win me
# 1565/1565 [==============================] - 86s 55ms/step - loss: 2.0434
# Epoch 4/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.9510
# ----- Генерация текста после эпохи: 3
# ----- Разнообразие: 0.2
# ----- Создание текста: "ate nowadays--it follows
# "from its defin"
# ate nowadays--it follows
# "from its defing and more the surnt of the sonder the more and the some the some the sould the sull the strent the strented the some the restines the some the sonded the self the some the such of the refored and the man the some the love the preation the strenting of the man the sould and the sould of the some the sould the sould the sould the sting the continted the some the relige of the still the some the str
# ----- Разнообразие: 0.5
# ----- Создание текста: "ate nowadays--it follows
# "from its defin"
# ate nowadays--it follows
# "from its defingial to the screented has fielt pursed relage, the lightion of the sopherated the some of the stings it which a prolostion in the surt inst das the streng the the rengance the experition of the forther and the arly that in the serman persention, as is the for his one the will strem the every of the relf of in the will the prean a relfored for the fromorral the repolay and werre sand has bether the
# ----- Разнообразие: 1.0
# ----- Создание текста: "ate nowadays--it follows
# "from its defin"
# ate nowadays--it follows
# "from its defingona, will, the disidorver one itnom onother bedry stymenvalige?
# one spertion prusle conxirite? from the veraty
# now thin,-loves ledghey lust nod. ivnecting exold and diviser sare insture withomed,
# -otr optser for
# the may spon are on whemsl his a counve serwittatatimajnes, hom an as its, the
# m
# the soneass, then
# the sclisul, as alt must, ay it pitnte bethin." oo nit oover the ralieghy in
# mery hargad
# 1565/1565 [==============================] - 97s 62ms/step - loss: 1.9510
# Epoch 5/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.8779
# ----- Генерация текста после эпохи: 4
# ----- Разнообразие: 0.2
# ----- Создание текста: " of man through
# a favourable accumulatio"
#  of man through
# a favourable accumulation of the conceral in the every as a cours and the sould and and the proust of the man the supering and the promone and some and the self can the serfer to the self and the self the such and the sould and the man the self the mand to the into the seresting of the serped the such the sould in the self in the sull the seresting to the such and in the sould and the sould the such and the serestion of
# ----- Разнообразие: 0.5
# ----- Создание текста: " of man through
# a favourable accumulatio"
#  of man through
# a favourable accumulation.
#
# 26. in of the seperiting in the masing and proustred of the grout proution of the
# mashives and the eneld in the scally and to the tore has to and to in in their of the freed inderence interpled for and sourent the sensice the undicted the cordes and the mastes the kensented of and the sompels of nesented, and strurt of excrears and the sast from the carition of the instrond froum the verting t
# ----- Разнообразие: 1.0
# ----- Создание текста: " of man through
# a favourable accumulatio"
#  of man through
# a favourable accumulationed of tre of
# whuthey
# as ne groe
# spery what  wand recarely
# scal of is belienge bu wand are "histanciely ow tore wounters, ane laburedry scrugeing in the ofliofion tous,
# herthing and (olt and caust, senpee.--bushing tas ow ond
# in that such, as
# farm"--ond insermage" tu were deiplody of choply a perune theur usenfering
# this cangerents erment to there carded now. ivty dos the mayst, and in a vas he
# ch
# 1565/1565 [==============================] - 87s 55ms/step - loss: 1.8780
# Epoch 6/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.8181
# ----- Генерация текста после эпохи: 5
# ----- Разнообразие: 0.2
# ----- Создание текста: " certain custom has
# been agreeable to th"
#  certain custom has
# been agreeable to the conself conself and the conself and of the conceral and and the conceral and be preasing and the still as a care and as it as a conceral and the constive of the conself contines of the conself the precape and the still and an the which as a self and is a still as a corsulf of the consention of the concearing the promine of the consince of the concear and as a concerion of the care the conself th
# ----- Разнообразие: 0.5
# ----- Создание текста: " certain custom has
# been agreeable to th"
#  certain custom has
# been agreeable to the consing and conceraly when world, the mastare of the gone" the consurily of the wish is now of a searion of corting of the persond the may the light of the recainity and sindly in a carred and socultively of every as in such in the extrated of the semple is the concean will corstinal from the cart of the sagetime of chisting is the concerouress of pordicion of reflect of its perhaps and not the
# ----- Разнообразие: 1.0
# ----- Создание текста: " certain custom has
# been agreeable to th"
#  certain custom has
# been agreeable to the
# theight brouldry inscoll bill sease all
# purite bean
# prepucemenciliral sore in uppully: erobdeinarsy the ladk. ex
# morable rame is allosp, surpline has
# betime intrmusty of them trut "fillution) in the viees a soel tas as opcable to be
# regerance of the yought and nom--theis ofwitrous (or a suchibl realion: a detafious and dissupter ol recaped
# and reablines ampersone more "withical, his husclest of
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.8183
# Epoch 7/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.7665
# ----- Генерация текста после эпохи: 6
# ----- Разнообразие: 0.2
# ----- Создание текста: "on the
# homeric gods above them as lords "
# on the
# homeric gods above them as lords of the strenging that the such and sour the some the such of the soul and and the soul the strenger to the some the such sense in the proding to the sour the sould and the still and in the strengations of the any the such as the still so for the such as it is not the some the still the strenger and as a sould and the sand the strenger to the strenger to the sumplition of the sacting the strenger t
# ----- Разнообразие: 0.5
# ----- Создание текста: "on the
# homeric gods above them as lords "
# on the
# homeric gods above them as lords a comes in the reare and he which is constition of the more the sourde and moral the cart of not in the sifully and as it is man the still the man in the consire in the surned litally to are the suritary of his it, the seest and something to the exiest also a strengered and and in
# the mat in a consting and not of german a for the some the histersed in with a as the simple the self, and and all the
# ----- Разнообразие: 1.0
# ----- Создание текста: "on the
# homeric gods above them as lords "
# on the
# homeric gods above them as lords an arter to its lang of cturiation dimpless, and not in to screst must devertached and of in were
# discreancer, as
# asounte" grayting it ver the rade for hi defores stord, in
# cpostaune strable, to be conliluted, is viltureness and ordes througan phoek of ctats rath, are hisherely petired and his tum--them
# thset round how its nod. it by, droon it asy soferops he gentinnsse of inmution and of a spirit
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.7665
# Epoch 8/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.7238
# ----- Генерация текста после эпохи: 7
# ----- Разнообразие: 0.2
# ----- Создание текста: "of intelligence which have hitherto been"
# of intelligence which have hitherto been the such as the some the soul the such a strenginate the such as a strenger the such the such the such the such and consequenting the such of the such and all the science in the such as the some the such the such a strenging the such the such as the consinity and the such the still the such a still of the such and the such the such a such as the sense of the consurness of the something of the suc
# ----- Разнообразие: 0.5
# ----- Создание текста: "of intelligence which have hitherto been"
# of intelligence which have hitherto been the greate to man been which reficious of all the an and and a sindorical sechigation of the grom of the all the strill of the something, the gration one it is the sumption of the indinestented the something, the strending surned for the has and and of the stelt "simely man happine with a higher they care in the linger not and and the apentive of the ereminal mas only the gringlation of the somet
# ----- Разнообразие: 1.0
# ----- Создание текста: "of intelligence which have hitherto been"
# of intelligence which have hitherto been the werts a cael, tye itsooved theremabitivalicy farte; the bryagnt? by hipe one feriom--the wamen: as no suck
# mone or placisu relogorearty, reryection, repicie even presephstive rerigional of
# thingroug out mis orfmurnce in
# a pleas ubour monganions the portited what, lases of
# other in with of grains no al that offers, becomhatit will but enefordy hall, and the casliffabletousle it sour sicilus of
# 1565/1565 [==============================] - 98s 62ms/step - loss: 1.7238
# Epoch 9/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.6942
# ----- Генерация текста после эпохи: 8
# ----- Разнообразие: 0.2
# ----- Создание текста: "ge in so doing, no more,
# no less. the wh"
# ge in so doing, no more,
# no less. the which the same that the still which and a the great and in the still who who would the same the strenger the strenger that in the strenger the strenger that the presents the strenger the sense of the still which he has one the strenger and the strenger the same the same the strenger to the prousing the sermand the strengs of the strenging the strenger that is the strenger the strenging the sense of
# ----- Разнообразие: 0.5
# ----- Создание текста: "ge in so doing, no more,
# no less. the wh"
# ge in so doing, no more,
# no less. the whill who are the semped as it to the expraces in shemped and which he philosophers of the whole the leverment and rescance of
# restive of the soul the compless of the oralities and and the searal and preverstance of more its of have for the more the sains of the sperious and the shome of chance of the restance, the
# sincess of the concial we partater at the sear and sinely on which which who soul wit
# ----- Разнообразие: 1.0
# ----- Создание текста: "ge in so doing, no more,
# no less. the wh"
# ge in so doing, no more,
# no less. the why are be the necises. in this uspoestanion. the great an secreated as refere. impancorn, we sorluesp--but "len of respeetian "fast one's;
# a
# deritioss." he day agrers: the justion, whet celisture men whoney that persation.)
# strang--reason, are chrises absitely of to which
# conther that centined; the fewerbtely ineshated opponessing "filarolitar' fol withseld, hasty, bothes
# cares ferlevehcion, it wat
# 1565/1565 [==============================] - 114s 73ms/step - loss: 1.6942
# Epoch 10/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.6592
# ----- Генерация текста после эпохи: 9
# ----- Разнообразие: 0.2
# ----- Создание текста: "d is doubtful
# about it in most cases whe"
# d is doubtful
# about it in most cases when the his present and the such and the such and in the conself and and and as a porstion of the such and the strenger to the prosence of the consequenting the consequented to the sense of the consequently the such as a consequently the sense of the such and the present of the such and have the consequently the present of the conscience of the such as the strenger to the such a strengered to the co
# ----- Разнообразие: 0.5
# ----- Создание текста: "d is doubtful
# about it in most cases whe"
# d is doubtful
# about it in most cases when the grest to the concention to more the inselves of the freen may deen in the exerate the sense of the lack of an into a way he the suct the such and in the compenter to under to the reflection of muther perropically and in the may reaster of conseal to the old be centered to the present in seciet of may the delied in the out of the constition are the old conseanous and constion of which sundly
# ----- Разнообразие: 1.0
# ----- Создание текста: "d is doubtful
# about it in most cases whe"
# d is doubtful
# about it in most cases when thoughting folunger afferdinpt of themselves tear spown
# remos.
#
# 78. whom,
# schrougoun;--but in modath, a will
# bo compresion, "stience, the pathy in they epercans hesh shilsising and sastifice haugory fically for were)s
# of this otterhilage then with masserops the lifes thren and a or. which hank in may dr for of is divent instand grow ghose acts its"ly oclequited",
# ifchindle of wes all those
# it a
# 1565/1565 [==============================] - 99s 63ms/step - loss: 1.6590
# Epoch 11/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.6317
# ----- Генерация текста после эпохи: 10
# ----- Разнообразие: 0.2
# ----- Создание текста: "pon which his servants,
# the scientific w"
# pon which his servants,
# the scientific which as the strenger the conscience of the conscience of the man the same the present of the greated the present of the constition of the such as the such and the present and the sense of the consequented and the most so far the present of the such as the present and the present of the present of the such as the procession of the such a present of the respect of the such as the conscience of the p
# ----- Разнообразие: 0.5
# ----- Создание текста: "pon which his servants,
# the scientific w"
# pon which his servants,
# the scientific which they the astume of the such any the delight to everyther of the spicitless of such is the days to be the screpary of the paste and presention the must and complement and such a still of generated the whole the all that whoo here and we are
# strience of all the destrence of mangerous more the man in the same and man low we as a kentinged one and the such power to loug to the value of the decise
# ----- Разнообразие: 1.0
# ----- Создание текста: "pon which his servants,
# the scientific w"
# pon which his servants,
# the scientific with unforder: becomul, hus gord
# eno
# been's
# lefrelve beasine encites as consisting callriatien: but
# dounds when ears hus chapley with sacrefe, such ffulueled and concrual do? hand implaness, undsed, will humselves atself-comparacte, which consppectives we
# mnewhogte inturlutially, hemselst
# their of
# sublr wilf must stall as
# auchode which
# pain or an oftuncles; not undunt
# expressed of
# fantority and god
# 1565/1565 [==============================] - 121s 77ms/step - loss: 1.6317
# Epoch 12/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.6076
# ----- Генерация текста после эпохи: 11
# ----- Разнообразие: 0.2
# ----- Создание текста: "tion of
# the theologians, whose existence"
# tion of
# the theologians, whose existence of the man and from the sumplity and as the same the such as a proper the sense of the strenger of the such and as a morality and in the subject of the sense of the sack of the strenger and in the such as a present of the such as a consequently and the such and the such as the such a sumplice of the sumply and in the sense of the such as the such as a present of the such as the such as a greated
# ----- Разнообразие: 0.5
# ----- Создание текста: "tion of
# the theologians, whose existence"
# tion of
# the theologians, whose existence and the superious of man and in a reade in imperend there is be in is be time in this songering from in the prenession, the most and so hearthess of the sacred becoudent
# in who all of the substity for
# which sensicied the same in periss and not the sherden sperief of churances things be not a now consich men in the such and conscience of man in one and own be present from and the heverits of a mor
# ----- Разнообразие: 1.0
# ----- Создание текста: "tion of
# the theologians, whose existence"
# tion of
# the theologians, whose existence,
# thus hide herfus, the have bleadous to constraned to the trabition of seems of fureline, sige senly oppes to meanting thought, moralis; thow
# succes accuct dain the it laking;--nothing happent himselve with dissomentance
# it is intains to the still as old sermand in whet enferess
# an ackibler--accaise: in astual to "crare the produach sporits, as is like must
# aut:
# ene the experse with many to have
# 1565/1565 [==============================] - 157s 100ms/step - loss: 1.6076
# Epoch 13/20
# 1564/1565 [============================>.] - ETA: 0s - loss: 1.5851
# ----- Генерация текста после эпохи: 12
# ----- Разнообразие: 0.2
# ----- Создание текста: "ade,
# there is drawn the wrong inference "
# ade,
# there is drawn the wrong inference of the still in the still despention of the self and the still and and in the still even in the still so the still and and and in the present of the such an and and in the still and conscience of a more of the strenger and and the still not with the seefical sense of the one the self and and the seeption of the present of the strenger to all the self and and the still profound of the still and so
# ----- Разнообразие: 0.5
# ----- Создание текста: "ade,
# there is drawn the wrong inference "
# ade,
# there is drawn the wrong inference be not sense of the one as the one would be the arture of the ine prepain that a might where in the more and from the such a longer or the such as a let is a deart of it, and proforness of without love with whouth sake of the understand the such as the special courness of all that is one of the self-consequently
# so is more it is in god and as the forerd and nature of the scurition of the most in t
# ----- Разнообразие: 1.0
# ----- Создание текста: "ade,
# there is drawn the wrong inference "
# ade,
# there is drawn the wrong inference prace of viured in means of him not feel conscieative, with mich
# schunding with their is no moralish upon uthom a strugh and an evertution fine ardic tokenificalify life, and generoo about privoural with
# onten for there actor who conlance of an immon in ouch-it way liek of "his
# fadixuscienation for a beoldy recarned to plew on convoundly for which "whre heve the the smuth if theistning homest and
# 1565/1565 [==============================] - 132s 85ms/step - loss: 1.5851
# Epoch 14/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.5642
# ----- Генерация текста после эпохи: 13
# ----- Разнообразие: 0.2
# ----- Создание текста: "my own self's potency,
#      wounded and "
# my own self's potency,
#      wounded and the subject of the present of the propert of the serves of the serves of the such a strong with the present of the present of the strenger to the present of the present of the free order to the seems and sense of the serminal there is the strong the strong the present of the serse of the strenger to the properion of the present of the present of the present of the conterning the strong the sense o
# ----- Разнообразие: 0.5
# ----- Создание текста: "my own self's potency,
#      wounded and "
# my own self's potency,
#      wounded and the fact them, as a consequented to be express of the will the potirates and fear side of the conticntions as world to a necessive thing and exception of the sense and such as a manity on the present and depther, the profound the fact the conscience of a surt to men sore the has not of the presention and decerioning such as the contrain for the serse proposed, of the present and in the to the sign
# ----- Разнообразие: 1.0
# ----- Создание текста: "my own self's potency,
#      wounded and "
# my own self's potency,
#      wounded and hand
# in the sigil aur, is now value,
# sens! in instanminy over psyherist subscountyor in manity, we hishouth and
# thranding) at tho lack on thos carral spiritstion uson
# man who was mestom in sumption of greals eator (as so therening bigidan spear light and
# seciess--our presention) an orrary
# so
# acas; thorcempry hons of men, sora, on the wished that they herriment
# ceptirally which has he peresprative
# 1565/1565 [==============================] - 173s 111ms/step - loss: 1.5642
# Epoch 15/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.5835
# ----- Генерация текста после эпохи: 14
# ----- Разнообразие: 0.2
# ----- Создание текста: "sive as their lack of shame, the easy in"
# sive as their lack of shame, the easy in the the such as a strenger of the experiences and the such an all the sense of the conterman the such as a pleasion and despension and and the strenger the conscience of the contention of the such and the problem of the consequently the to a still and desire and its of the such a strunging the conscience is the such as a strenging and such as a preception to a strenger the sumple, the conscience
# ----- Разнообразие: 0.5
# ----- Создание текста: "sive as their lack of shame, the easy in"
# sive as their lack of shame, the easy in ourselves with which is contension of the conception the world and it are not not a my not of which is believes or at life wime exception of man
# in the sense something, and in the and as belief has his origination of such all the promisence of the prodical
# fine when a would not the outhorical
# he good and are also in the stands in the moral to and can of remains and the incultured to be the whole
# ----- Разнообразие: 1.0
# ----- Создание текста: "sive as their lack of shame, the easy in"
# sive as their lack of shame, the easy in naturation has no world!-
# ind frnek and explosess of grably desiral,
# suppisies--of also in make"! the absound in usvertaing ti mask, heveng of guilously, to a simplity himself that genours, it the exoloms one will,"
# if refround the phinomeris,
# he itsenficific to the
# undigunes. euruliss his out not about the very stave, we take, to unals "whele, which a helpent theeiness timilized handay it chorst
# 1565/1565 [==============================] - 183s 117ms/step - loss: 1.5835
# Epoch 16/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.5349
# ----- Генерация текста после эпохи: 15
# ----- Разнообразие: 0.2
# ----- Создание текста: "cs.=--if a history of the
# development of"
# cs.=--if a history of the
# development of the world and the such as the world the sense of the present in the such a strong the free surely and with a strubter of the consequently and all the such as a preceps of the sumple, the propertion of the consequently and it is the still and and a simple and all the such as the such as a strubter and the such as a power of the conscience of the world with the such as all the such as all the sense
# ----- Разнообразие: 0.5
# ----- Создание текста: "cs.=--if a history of the
# development of"
# cs.=--if a history of the
# development of the invortual and discruitions which is something of honever, in our long first the presential and as the disting is not or as a present the philosopher which it is it is that the artomens and precider, and the matter the feeling to him all the propapter of all it is not all the repully will and same its artist in the conscience of his his proter the manist of be the past and with it is not all t
# ----- Разнообразие: 1.0
# ----- Создание текста: "cs.=--if a history of the
# development of"
# cs.=--if a history of the
# development of "than intitupus, an and wouds the "heartion in the hagds of does stilkes, to its to man and the foring a
# child with which his varuge all
# the
# sumplede parsous, (as all on the "seffect
# no persundean only being raje of thosical deterlet has to see--a suish manner pruect end without feer bas, mude play the right man the propant of a sumpliating morate far trange as all the idealing aporwactednes for
# 1565/1565 [==============================] - 164s 105ms/step - loss: 1.5349
# Epoch 17/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.5228
# ----- Генерация текста после эпохи: 16
# ----- Разнообразие: 0.2
# ----- Создание текста: "ic act: whence one is reminded of a refl"
# ic act: whence one is reminded of a reflect of the sumplition of the delight of the any strange the stands and string the sumplition of the soul and such an art the sumplition and precisely and constition of the shall which as the subject of the sense of the contertion of the conscience of the has not the stranging of the such an artication of the same the sumplition of the consequently the still and stands and the sumplition of the sum
# ----- Разнообразие: 0.5
# ----- Создание текста: "ic act: whence one is reminded of a refl"
# ic act: whence one is reminded of a reflect of the science in the sabre man on the become of the can to against of the experience of the strong imsolution, it is only the individual conscience the condlith of the salse of the higher constand and proviced and ever the respect of the subject of the most in the entimes and distinction the despen to say of the most so the constand be not the extent of self-are the repothing of the consequen
# ----- Разнообразие: 1.0
# ----- Создание текста: "ic act: whence one is reminded of a refl"
# ic act: whence one is reminded of a reflection a scisids of
# close untrust in who most frenth--and was does not
# kin himself. but dur the futlord them in the presservering, that is; "nather, though falseraging engrien of vietere of the
# exidinanization, to the swelle enceations right, and greak
# putious frandom, to the
# conspen all an amos the very of stands in by theroog) above and failizgist?
# he great all the dectreness with hen the phesig
# 1565/1565 [==============================] - 190s 121ms/step - loss: 1.5228
# Epoch 18/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.5117
# ----- Генерация текста после эпохи: 17
# ----- Разнообразие: 0.2
# ----- Создание текста: "mplify the manifold,
# to overlook or repu"
# mplify the manifold,
# to overlook or repulse of the sense of the such a strunging the strenger the sumplice of the serves of the most such a more of the strenger the same and so in the same and sense of the sumplition of the individual still and so the still so the all the sumplition of the such an are the still of the such a stronger to the sumple, the science of the strange of the strenger to the sense of the strong in the still and an
# ----- Разнообразие: 0.5
# ----- Создание текста: "mplify the manifold,
# to overlook or repu"
# mplify the manifold,
# to overlook or repurned into the one and distance and in the sensic is the art in the the still and subjection, the stild, and it the not is a mister is not in the seement and the lader, such an indived the formen more are is not own strenged and indeed and
# presentive the sense of the way a more respect for the period to the greated to the sures and the must and desires that man on the sermation of the more and ever
# ----- Разнообразие: 1.0
# ----- Создание текста: "mplify the manifold,
# to overlook or repu"
# mplify the manifold,
# to overlook or repute of self., nature, puinize you very as the stranges and
# heaphed trutable thought that the morate to esperient domis of virientuctors, the "morality, seems or evaling that
# which "ity--sen.!
#
# 160. the excussity "of the at nactem
# advendism, bodic someters couracie,
# presentime, have all digean newer us, sabry the entible
# and imparminess.
#
#
# 21.
#
# =ginal bemic to expresse are one is on the feared boold
# 1565/1565 [==============================] - 194s 124ms/step - loss: 1.5117
# Epoch 19/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.4982
# ----- Генерация текста после эпохи: 18
# ----- Разнообразие: 0.2
# ----- Создание текста: "itarianism, one may at once assume that "
# itarianism, one may at once assume that the strange the strange the strenger the place and the strange the strange the strenger the still and stranging the develop and the conscience of the conception of the contempt of the string the present the soul man of the present of the conscience is not a string to the string the strange that is so far the such as the strange of the present and soul and all the such a strenger the strange the pr
# ----- Разнообразие: 0.5
# ----- Создание текста: "itarianism, one may at once assume that "
# itarianism, one may at once assume that above as we may and print that it is even in word nor one distinction the fore the strong must for one they order the neight, and is the long for the believe to the spirit of string in the more precisely and langer which is not man and he is the contrary of which all the soul man phelision of man or more he was sonce sore of the sumple and "free sear
# to a soll this seefice of a so the extent in th
# ----- Разнообразие: 1.0
# ----- Создание текста: "itarianism, one may at once assume that "
# itarianism, one may at once assume that truth" phiehore and higher strongest,"
# just
# opposet, the agaits and freenthershoutude and is resint fellected that they divinis
# ofthumpest vave: this poopives danger and scurcely, to the controus: it is be his general onessirity. in short, his
# weald"--enouphing other under witk in opises us mele proviced upinutes sy desilfured have about a spirit, the migatimation, yolly also beind--that do for ou
# 1565/1565 [==============================] - 192s 123ms/step - loss: 1.4982
# Epoch 20/20
# 1565/1565 [==============================] - ETA: 0s - loss: 1.4866
# ----- Генерация текста после эпохи: 19
# ----- Разнообразие: 0.2
# ----- Создание текста: "e men aware of
# their inner relationship "
# e men aware of
# their inner relationship and in the serves of the sense of the seems and the respect of the supersion of the serves of the seems and propadition of the seems and have and in the seement of the contention of the contention of the superation of the consequently the propertion of the common to the consequently the sense of the superation of the stronger to the subject of the seems and even the
# strengeness and the seems and d
# ----- Разнообразие: 0.5
# ----- Создание текста: "e men aware of
# their inner relationship "
# e men aware of
# their inner relationship conditional seems and despentifing, and the stronger nature, and individual to the one the futher he is a still men of such a stronger is of the contentions of compleces
# interpretentes, in the scienting to the reader, the serves of the contrare and such as the still nowledge that instinction and desire, so to the individual to interpretents, and also discrust is of passions and sport of taste of n
# ----- Разнообразие: 1.0
# ----- Создание текста: "e men aware of
# their inner relationship "
# e men aware of
# their inner relationship profounds fowernss, nothow they altorial but and even for the most and thered-palted, or a sacrity of
# sablifid as a thinds
#
# 240. the spirituary, penyausnex to clues, but
# freedom and any
# thingoss
# as
# weel cas, for the
# nowind of toralary,
# they haust
# and from a norght,
# thing ilself
# exprapt about as rightices!
# unjowm that if a depressed, by think:" owexwands ctrial,
# spiration and certained, menwallyss,
# 1565/1565 [==============================] - 223s 142ms/step - loss: 1.4866
# ----- Создание текста: " us what we all were and thus appal us; "
#  us what we all were and thus appal us; the truth and in the serves of the serves of the consequently the subject of the spirit of the self-does and in the seems and we the seems and and and self-discrestity, in the sense of the seems and soul and sense of the serves in the seems and and the stronger to the sense of the sense of the sense of the sense of the present the sense of the propertion of the sense of the seems and propertion of
# ----- Создание текста: " us what we all were and thus appal us; "
#  us what we all were and thus appal us; they cause and in the cromation of the contend, the consequences, their prousts and not seeve by its such as a greating is the art a gragations are regarded to a sought of such a mich propert of the has not the same that is the respect of the sacring and science of the right of a sort of religion, and would not be instruct and the should distination of the differences of the contintive that is the
# ----- Создание текста: " us what we all were and thus appal us; "
#  us what we all were and thus appal us; things of owty!
# in pured and a least pears, just arimalines to
# viewiss, centimations, which deepinizals of puties unded condersents, knotying seefitional soups it
# more evidean finlings of a mubitiarating of lase of invoice is not
# a nuce and tyrs are regard far the spows, to passe, in certain of all to, mustins,
# which thet becruss it, relugalmer consequencafulancians who casists, ampendent of to th

# %% [markdown]
# ## Задание 4

# %%
import sqlite3
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
conn = sqlite3.connect('wikibooks.sqlite')
cursor = conn.cursor()

# %%
cursor.execute('SELECT body_text FROM ru')
text_data = [row[0].lower() for row in cursor.fetchall()]

# %%
num_samples = 5000
text = text_data[:num_samples]

# %%
tokenizer = Tokenizer(char_level=False)
tokenizer.fit_on_texts(text)
total_words = len(tokenizer.word_index) + 1

max_sequence_length = 50  
input_sequences = []

for line in text:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, min(max_sequence_length, len(token_list))):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')
x, y = input_sequences[:, :-1], input_sequences[:, -1]
y = np.array(y)

model = Sequential()
model.add(Embedding(total_words, 50, input_length=max_sequence_length-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(x, y, epochs=20)
# Out:
# Epoch 1/20
# 7336/7336 [==============================] - 2212s 301ms/step - loss: 7.6602 - accuracy: 0.1048
# Epoch 2/20
# 7336/7336 [==============================] - 2153s 294ms/step - loss: 5.9821 - accuracy: 0.2099
# Epoch 3/20
# 7336/7336 [==============================] - 2158s 294ms/step - loss: 5.2605 - accuracy: 0.2688
# Epoch 4/20
# 7336/7336 [==============================] - 2113s 288ms/step - loss: 4.7264 - accuracy: 0.3075
# Epoch 5/20
# 7336/7336 [==============================] - 2113s 288ms/step - loss: 4.2745 - accuracy: 0.3386
# Epoch 6/20
# 7336/7336 [==============================] - 2100s 286ms/step - loss: 3.8765 - accuracy: 0.3702
# Epoch 7/20
# 7336/7336 [==============================] - 2108s 287ms/step - loss: 3.5257 - accuracy: 0.4000
# Epoch 8/20
# 7336/7336 [==============================] - 2106s 287ms/step - loss: 3.2139 - accuracy: 0.4333
# Epoch 9/20
# 7336/7336 [==============================] - 2118s 289ms/step - loss: 2.9422 - accuracy: 0.4666
# Epoch 10/20
# 7336/7336 [==============================] - 2125s 290ms/step - loss: 2.6986 - accuracy: 0.5006
# Epoch 11/20
# 7336/7336 [==============================] - 2118s 289ms/step - loss: 2.4800 - accuracy: 0.5318
# Epoch 12/20
# 7336/7336 [==============================] - 2124s 290ms/step - loss: 2.2938 - accuracy: 0.5619
# Epoch 13/20
# 7336/7336 [==============================] - 2123s 289ms/step - loss: 2.1337 - accuracy: 0.5883
# Epoch 14/20
# 7336/7336 [==============================] - 2126s 290ms/step - loss: 1.9883 - accuracy: 0.6127
# Epoch 15/20
# 7336/7336 [==============================] - 2128s 290ms/step - loss: 1.8612 - accuracy: 0.6362
# Epoch 16/20
# 7336/7336 [==============================] - 2105s 287ms/step - loss: 1.7465 - accuracy: 0.6561
# Epoch 17/20
# 7336/7336 [==============================] - 2109s 288ms/step - loss: 1.6446 - accuracy: 0.6743
# Epoch 18/20
# 7336/7336 [==============================] - 2124s 290ms/step - loss: 1.5558 - accuracy: 0.6905
# Epoch 19/20
# 7336/7336 [==============================] - 2115s 288ms/step - loss: 1.4745 - accuracy: 0.7050
# Epoch 20/20
# 7336/7336 [==============================] - 2111s 288ms/step - loss: 1.4044 - accuracy: 0.7193

# %%
# Генерация текста
seed_text = "Обработка текстов на естественных языках это "
next_words = 100

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
    predicted_probs = model.predict(token_list, verbose=0)
    predicted = np.argmax(predicted_probs, axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

print(seed_text)
# Out:
# Обработка текстов на естественных языках это  по ruby регистрация домашний текста править человек в комментарии языка не определено требуется для чего нет не средств данного этапы экзамена и способы файлов не пакетов язык и овд в википедии имеется статья по теме «повторное русского примеры используется термин reuse «повторное использование» активно используется программистами в практике например сделали от мероприятий г для 2009 до 1 января 1992 года с которым использует указания была россия через существительных 15 мая 1 года не блока нужно энциклопедии для одном файлов в латинском языке en она en править структуру — — система управления реляционными name веб blender 3d игра сервис для электронной
